# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from num2words import num2words
from collections import Counter
from scipy import spatial
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from scipy.special import gammaln
from collections import Counter
from textblob import TextBlob

import pickle
import gensim
import imp
import lda2
import scipy
import operator
import nltk
import os
import string
import numpy as np
import copy
import pandas as pd
import pickle

# %%
def processReviews(reviews, window=5, MAX_VOCAB_SIZE=1000):
    vectorizer = CountVectorizer(analyzer="word",tokenizer=None)
    train_data_features = vectorizer.fit_transform(reviews)
    words = vectorizer.get_feature_names()
    vocabulary = dict(zip(words,np.arange(len(words))))
    inv_vocabulary = dict(zip(np.arange(len(words)),words))
    wordOccurenceMatrix = train_data_features.toarray()
    return wordOccurenceMatrix, vocabulary, words

def get_cosine(a, b):
    return 1 - spatial.distance.cosine(a, b)

# %%
def coherence_score(X, topic_sentiment_df):
    X[X>1] = 1    
    totalcnt = len(topic_sentiment_df)
    total = 0
    for allwords in topic_sentiment_df:
        for word1 in allwords:
            for word2 in allwords:
                if word1 != word2:
                    ind1 = vocabulary[word1]
                    ind2 = vocabulary[word2]
                    total += np.log((np.matmul(X[:,ind1].T, X[:,ind2]) + 1.0)/np.sum(X[:,ind2]))
    return total/(2*totalcnt)

def kl_score(pk,qk):
    return (scipy.stats.entropy(pk,qk)*.5 + scipy.stats.entropy(qk,pk)*.5)

def get_hscore(dt_distribution, X, k):
    testlen = X.shape[0]
    all_kl_scores = np.zeros((testlen, testlen))
    for i in range(testlen-1):
        for j in range(i+1,testlen):
            score = kl_score(dt_distribution[i],dt_distribution[j])
            all_kl_scores[i,j] = score
            all_kl_scores[j,i] = score

    dt = np.zeros((X.shape[0], k))

    for i in range(X.shape[0]):
        dt[i, dt_distribution[i].argmax()]=1

    intradist = 0
    for i in range(k):
        cnt = dt[:,i].sum()
        tmp = np.outer(dt[:,i],dt[:,i])
        tmp = tmp * all_kl_scores
        intradist += tmp.sum()*1.0/(cnt*(cnt-1))
#         print(cnt, tmp.sum(), intradist)
    intradist = intradist/k
    

    interdist = 0
    for i in range(k):
       for j in range(k):
           if i != j:
             cnt_i = dt[:,i].sum()
             cnt_j = dt[:,j].sum()
             tmp = np.outer(dt[:,i], dt[:,j])
             tmp = tmp * all_kl_scores
             interdist += tmp.sum()*1.0/(cnt_i*cnt_j)
    interdist = interdist/(k*(k-1))
    return intradist/interdist

# %%
# %%time
embeddings_index = gensim.models.KeyedVectors.load_word2vec_format('pubmed2018_w2v_200D/pubmed2018_w2v_200D.bin', binary=True)
# Out:
# /root/miniconda3/envs/python2/lib/python2.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# CPU times: user 3min 25s, sys: 5.87 s, total: 3min 31s
# Wall time: 3min 31s

# %%
icd_words = pd.read_csv("strict_medical_words.txt", header=None)[0].values.tolist()

# %%
# icd_words = pickle.load(open("unique_words.pickle",'rb'))

# %%
dataset = pd.read_pickle("dataset_cleaned_autocorrected")

# %%
dataset[8] = dataset[7].apply(lambda x: [item for item in x.split(" ") if item in icd_words])
dataset[9] = dataset[8].apply(lambda x: " ".join(x))

# %%
dataset.to_pickle("dataset_cleaned_autocorrected_strict_medical_only")

# %%
matrix, vocabulary, words = processReviews(dataset[9].values)

# %%
def grid_search(N_TOPICS, lambda_param, edges_threshold):
    k = N_TOPICS
    docs_edges = []
    count = 0
    ignored = []
    taken = []
    for idx, doc in enumerate(dataset[8].values):
        edges = []
        for i in doc:
            for j in doc:
                if i != j:
                    try:
                        a = embeddings_index[i]
                        b = embeddings_index[j]
                        if get_cosine(a, b) > edges_threshold:
                            edges.append((vocabulary[i], vocabulary[j]))
                    except:
                        try:
                            embeddings_index[i]
                            taken.append(i)
                        except:
                            ignored.append(i)
                        try:
                            embeddings_index[j]
                        except:
                            ignored.append(j)
                            taken.append(j)
                        pass
        docs_edges.append(edges)

    edge_dict = {}
    for i in docs_edges:
        for j in i:
            try:
                edge_dict[j[0]] += [j[1]]
            except:
                edge_dict[j[0]] = [j[1]]
    sampler = lda2.LdaSampler(n_topics=N_TOPICS, lambda_param=lambda_param)

    for it, phi in enumerate(sampler.run(matrix, edge_dict)):
        sampler.loglikelihood(docs_edges)



    t_words = sampler.getTopKWords(5, words)
    top_words = [t_words[i] for i in t_words.keys()]

    return coherence_score(matrix, top_words), get_hscore(sampler.theta(), matrix, k), t_words, sampler.theta()

# %%
N_TOPICS = [7, 9]

# %%
edges_threshold = [0.3, 0.5, 0.7]

# %%
lambda_param = [0.3, 0.7, 1.0]

# %%
dump = []
for i in N_TOPICS:
    for j in edges_threshold:
        for k in lambda_param:
            dump.append((i, j, k, grid_search(N_TOPICS=i, edges_threshold=j, lambda_param=k)))

# %%
for idx, i in enumerate(dump):
    print("")
    print(idx, i[0], i[1], i[2], i[3][0], i[3][1])
    for j in i[3][2]:
        print(i[3][2][j])
# Out:
# (0, 7, 0.3, 0.3, -9.10807374481516, 0.10943909337950633)
# [u'hiv', u'appendix', u'renal', u'urine', u'cell']
# [u'stage', u'distress', u'schedule', u'screening', u'sepsis']
# [u'anesthetic', u'radiation', u'node', u'radiotherapy', u'cancer']
# [u'non', u'sac', u'diabetic', u'hip', u'knee']
# [u'allergy', u'cyanosis', u'diagnostic', u'chemotherapy', u'consciousness']
# [u'allergy', u'abdominal', u'fever', u'oriented', u'lung']
# [u'artery', u'using', u'angioplasty', u'dominant', u'proximal']
#
# (1, 7, 0.3, 0.7, -8.432179062289256, 0.1548748443715706)
# [u'stage', u'diabetic', u'consciousness', u'cycle', u'event']
# [u'anesthesia', u'anesthetic', u'institution', u'genetic', u'sac']
# [u'preterm', u'stage', u'screening', u'due', u'respiratory']
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
# [u'urology', u'carcinoma', u'cancer', u'fever', u'abdominal']
# [u'wound', u'stomach', u'skin', u'hiv', u'urine']
# [u'murmur', u'pallor', u'cell', u'cyanosis', u'platelet']
#
# (2, 7, 0.3, 1.0, -7.781209655363294, 0.11603281069853029)
# [u'oriented', u'urology', u'surgical', u'allergy', u'abdominal']
# [u'kidney', u'lymphocyte', u'urea', u'platelet', u'cell']
# [u'fistula', u'uterus', u'murmur', u'pallor', u'cyanosis']
# [u'cancer', u'diabetic', u'consciousness', u'cycle', u'event']
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
# [u'multiple', u'hiv', u'cell', u'skin', u'urine']
# [u'due', u'screening', u'preterm', u'schedule', u'respiratory']
#
# (3, 7, 0.5, 0.3, -6.730249983153114, 0.11617335296941897)
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
# [u'urea', u'cyanosis', u'pallor', u'cell', u'platelet']
# [u'symptomatic', u'abdominal', u'oriented', u'wound', u'knee']
# [u'screening', u'stage', u'distress', u'preterm', u'respiratory']
# [u'cell', u'carcinoma', u'cancer', u'skin', u'urine']
# [u'anesthesia', u'sac', u'genetic', u'institution', u'anesthetic']
# [u'urology', u'cycle', u'consciousness', u'allergy', u'chemotherapy']
#
# (4, 7, 0.5, 0.7, -9.3731973621851, 0.12704269125897827)
# [u'lung', u'symptomatic', u'allergy', u'oriented', u'abdominal']
# [u'transfusion', u'restricted', u'multiple', u'knee', u'due']
# [u'renal', u'schedule', u'unilateral', u'hiv', u'urine']
# [u'uterus', u'fever', u'skin', u'pallor', u'ecg']
# [u'residual', u'angioplasty', u'proximal', u'using', u'artery']
# [u'diabetic', u'carcinoma', u'consciousness', u'event', u'cycle']
# [u'distress', u'preterm', u'schedule', u'screening', u'respiratory']
#
# (5, 7, 0.5, 1.0, -8.84918057417426, 0.17757852323135212)
# [u'angioplasty', u'residual', u'proximal', u'using', u'artery']
# [u'fever', u'stage', u'stomach', u'node', u'carcinoma']
# [u'cell', u'preterm', u'screening', u'schedule', u'respiratory']
# [u'abdominal', u'consciousness', u'surgical', u'allergy', u'event']
# [u'hiv', u'diagnostic', u'ecg', u'skin', u'lap']
# [u'fistula', u'due', u'trauma', u'arm', u'restricted']
# [u'schedule', u'institution', u'stone', u'anesthesia', u'unilateral']
#
# (6, 7, 0.7, 0.3, -7.870374556659437, 0.1102970361436285)
# [u'abdominal', u'consciousness', u'cycle', u'event', u'allergy']
# [u'appendicitis', u'skin', u'hiv', u'ecg', u'urine']
# [u'schedule', u'carcinoma', u'cancer', u'respiratory', u'sepsis']
# [u'preterm', u'respiratory', u'sepsis', u'fever', u'platelet']
# [u'wound', u'fistula', u'trauma', u'restricted', u'knee']
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
# [u'institution', u'genetic', u'anesthesia', u'anesthetic', u'unilateral']
#
# (7, 7, 0.7, 0.7, -7.625376498027707, 0.11987433964756496)
# [u'cell', u'hiv', u'skin', u'wound', u'urine']
# [u'carcinoma', u'diabetic', u'consciousness', u'cycle', u'event']
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
# [u'stage', u'preterm', u'platelet', u'schedule', u'respiratory']
# [u'renal', u'allergy', u'oriented', u'urology', u'abdominal']
# [u'uterus', u'murmur', u'cyanosis', u'hiv', u'pallor']
# [u'schedule', u'anesthesia', u'anesthetic', u'genetic', u'institution']
#
# (8, 7, 0.7, 1.0, -10.122212237327162, 0.1612353173273903)
# [u'stomach', u'urology', u'stage', u'platelet', u'fever']
# [u'immunization', u'schedule', u'renal', u'respiratory', u'diagnostic']
# [u'diabetic', u'cycle', u'allergy', u'consciousness', u'event']
# [u'residual', u'angioplasty', u'using', u'artery', u'proximal']
# [u'ecg', u'allergy', u'abdominal', u'surgical', u'urine']
# [u'anesthetic', u'node', u'genetic', u'anesthesia', u'carcinoma']
# [u'management', u'cycle', u'knee', u'restricted', u'wound']
#
# (9, 9, 0.3, 0.3, -6.673159782328078, 0.14155724449671767)
# [u'distress', u'immunization', u'preterm', u'schedule', u'respiratory']
# [u'schedule', u'anesthesia', u'anesthetic', u'institution', u'genetic']
# [u'cyanosis', u'uterus', u'murmur', u'pallor', u'diagnostic']
# [u'alveolus', u'node', u'global', u'carcinoma', u'stage']
# [u'knee', u'lung', u'oriented', u'surgical', u'unit']
# [u'tibia', u'management', u'restricted', u'oral', u'due']
# [u'diabetic', u'allergy', u'consciousness', u'cycle', u'event']
# [u'cell', u'stone', u'hiv', u'skin', u'urine']
# [u'residual', u'angioplasty', u'proximal', u'using', u'artery']
#
# (10, 9, 0.3, 0.7, -7.848455623969065, 0.16483691213503532)
# [u'precaution', u'lesion', u'aseptic', u'cystic', u'oral']
# [u'platelet', u'preterm', u'schedule', u'screening', u'respiratory']
# [u'global', u'stage', u'stone', u'renal', u'carcinoma']
# [u'parietal', u'special', u'weakness', u'dehydration', u'due']
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
# [u'ecg', u'cell', u'hiv', u'skin', u'urine']
# [u'anesthetic', u'cyanosis', u'schedule', u'institution', u'genetic']
# [u'allergy', u'wound', u'oriented', u'abdominal', u'knee']
# [u'diabetic', u'allergy', u'consciousness', u'cycle', u'event']
#
# (11, 9, 0.3, 1.0, -6.185689982542079, 0.1481487380084186)
# [u'unilateral', u'renal', u'restricted', u'stone', u'urology']
# [u'syndrome', u'complication', u'diagnostic', u'ecg', u'arm']
# [u'allergy', u'diabetic', u'consciousness', u'cycle', u'event']
# [u'node', u'radiotherapy', u'global', u'stage', u'cancer']
# [u'symptomatic', u'oriented', u'allergy', u'fever', u'surgical']
# [u'appendix', u'wound', u'skin', u'hiv', u'urine']
# [u'distress', u'preterm', u'platelet', u'cell', u'respiratory']
# [u'scrotal', u'anesthesia', u'anesthetic', u'institution', u'genetic']
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
#
# (12, 9, 0.5, 0.3, -6.7786722049718575, 0.15297194255958343)
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
# [u'symptomatic', u'knee', u'lung', u'oriented', u'abdominal']
# [u'anesthesia', u'genetic', u'institution', u'renal', u'anesthetic']
# [u'vomiting', u'ecg', u'hiv', u'skin', u'urine']
# [u'cyanosis', u'pallor', u'carcinoma', u'cancer', u'diagnostic']
# [u'urea', u'screening', u'preterm', u'schedule', u'respiratory']
# [u'replacement', u'cardiac', u'multi', u'trauma', u'restricted']
# [u'generalized', u'dura', u'oral', u'vara', u'fever']
# [u'diabetic', u'cycle', u'allergy', u'consciousness', u'chemotherapy']
#
# (13, 9, 0.5, 0.7, -8.274573620001517, 0.1917669020646436)
# [u'decreased', u'oral', u'trauma', u'transfusion', u'stage']
# [u'hydrocele', u'anesthesia', u'schedule', u'anesthetic', u'institution']
# [u'cell', u'wound', u'skin', u'hiv', u'urine']
# [u'stomach', u'multiple', u'due', u'radiotherapy', u'lung']
# [u'diabetic', u'allergy', u'cycle', u'consciousness', u'event']
# [u'screening', u'cell', u'schedule', u'preterm', u'respiratory']
# [u'node', u'symptomatic', u'unit', u'knee', u'abdominal']
# [u'pallor', u'uterus', u'murmur', u'cyanosis', u'ecg']
# [u'angioplasty', u'residual', u'using', u'artery', u'proximal']
#
# (14, 9, 0.5, 1.0, -6.626448727220165, 0.14064918343052565)
# [u'screening', u'stage', u'schedule', u'preterm', u'sepsis']
# [u'ecg', u'cell', u'skin', u'hiv', u'urine']
# [u'glucose', u'neutrophil', u'lymphocyte', u'urea', u'platelet']
# [u'routine', u'murmur', u'uterus', u'pallor', u'cyanosis']
# [u'angioplasty', u'residual', u'proximal', u'using', u'artery']
# [u'node', u'carcinoma', u'cancer', u'fever', u'abdominal']
# [u'restricted', u'oriented', u'trauma', u'joint', u'wound']
# [u'unit', u'allergy', u'consciousness', u'cycle', u'chemotherapy']
# [u'stone', u'institution', u'anesthetic', u'unilateral', u'schedule']
#
# (15, 9, 0.7, 0.3, -6.790363749613477, 0.11871529836833969)
# [u'distress', u'schedule', u'preterm', u'screening', u'respiratory']
# [u'schedule', u'anesthetic', u'institution', u'genetic', u'anesthesia']
# [u'stone', u'due', u'renal', u'joint', u'knee']
# [u'symptomatic', u'lung', u'allergy', u'oriented', u'surgical']
# [u'multiple', u'skin', u'ecg', u'hiv', u'urine']
# [u'management', u'allergy', u'consciousness', u'cycle', u'chemotherapy']
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
# [u'stage', u'pallor', u'uterus', u'murmur', u'cyanosis']
# [u'global', u'radiotherapy', u'node', u'cell', u'cancer']
#
# (16, 9, 0.7, 0.7, -8.566510585538282, 0.164814510909428)
# [u'appendicitis', u'skin', u'ecg', u'hiv', u'urine']
# [u'residual', u'angioplasty', u'using', u'proximal', u'artery']
# [u'transfusion', u'trauma', u'management', u'wound', u'restricted']
# [u'uterus', u'cyanosis', u'stage', u'node', u'cancer']
# [u'stomach', u'cell', u'chemotherapy', u'diabetic', u'fever']
# [u'chemotherapy', u'consciousness', u'respiratory', u'event', u'allergy']
# [u'abdomen', u'urology', u'stone', u'symptomatic', u'knee']
# [u'unilateral', u'schedule', u'institution', u'anesthetic', u'genetic']
# [u'cell', u'routine', u'urea', u'lymphocyte', u'diagnostic']
#
# (17, 9, 0.7, 1.0, -7.715471859153733, 0.1655139630228902)
# [u'stone', u'anesthetic', u'renal', u'institution', u'urology']
# [u'ecg', u'complex', u'skin', u'hiv', u'urine']
# [u'non', u'transfusion', u'lymphocyte', u'urea', u'platelet']
# [u'residual', u'angioplasty', u'proximal', u'using', u'artery']
# [u'allergy', u'diabetic', u'consciousness', u'event', u'cycle']
# [u'stage', u'arm', u'schedule', u'diagnostic', u'respiratory']
# [u'fistula', u'tibia', u'deformity', u'oriented', u'restricted']
# [u'radiotherapy', u'global', u'stage', u'node', u'cancer']
# [u'abdomen', u'allergy', u'knee', u'symptomatic', u'abdominal']

# %%
dataset[9][0]
# Out:
# u'multi trauma cerebrovascular accident fibula hemiplegia due parietal lobe weakness slurred associated special multi'

# %%
def plot_TSNE(dt_distribution):
    X_embedded = TSNE(n_components=2).fit_transform(dt_distribution)

    X = np.array([i[0] for i in X_embedded])
    Y = np.array([i[1] for i in X_embedded])
    C = dt_distribution.argmax(axis=1)
    for i in range(10):
        xx = X[[np.where(C == i)[0].tolist()]]
        yy = Y[[np.where(C == i)[0].tolist()]]
        plt.scatter(xx, yy, label=str(i))

    plt.title('Document-Topic Distribution')
    plt.legend(loc=(1.04,0))
    plt.show()
    
def get_doc_details(num):
    print("label: ", C[num])
    print(dataset[9][num])

# %%
dump[0]
# Out:
# (7,
#  0.3,
#  0.3,
#  (-9.10807374481516,
#   0.10943909337950633,
#   {0: [u'hiv', u'appendix', u'renal', u'urine', u'cell'],
#    1: [u'stage', u'distress', u'schedule', u'screening', u'sepsis'],
#    2: [u'anesthetic', u'radiation', u'node', u'radiotherapy', u'cancer'],
#    3: [u'non', u'sac', u'diabetic', u'hip', u'knee'],
#    4: [u'allergy',
#     u'cyanosis',
#     u'diagnostic',
#     u'chemotherapy',
#     u'consciousness'],
#    5: [u'allergy', u'abdominal', u'fever', u'oriented', u'lung'],
#    6: [u'artery', u'using', u'angioplasty', u'dominant', u'proximal']},
#   array([[0.00680272, 0.00680272, 0.00680272, 0.82312925, 0.14285714,
#           0.00680272, 0.00680272],
#          [0.03703704, 0.03703704, 0.03703704, 0.03703704, 0.03703704,
#           0.77777778, 0.03703704],
#          [0.01754386, 0.01754386, 0.01754386, 0.01754386, 0.01754386,
#           0.71929825, 0.19298246],
#          [0.01298701, 0.01298701, 0.92207792, 0.01298701, 0.01298701,
#           0.01298701, 0.01298701],
#          [0.00934579, 0.00934579, 0.85046729, 0.00934579, 0.00934579,
#           0.10280374, 0.00934579],
#          [0.00854701, 0.00854701, 0.94871795, 0.00854701, 0.00854701,
#           0.00854701, 0.00854701],
#          [0.01492537, 0.01492537, 0.01492537, 0.31343284, 0.6119403 ,
#           0.01492537, 0.01492537],
#          [0.01492537, 0.01492537, 0.1641791 , 0.76119403, 0.01492537,
#           0.01492537, 0.01492537],
#          [0.00934579, 0.00934579, 0.00934579, 0.94392523, 0.00934579,
#           0.00934579, 0.00934579],
#          [0.01754386, 0.01754386, 0.01754386, 0.54385965, 0.36842105,
#           0.01754386, 0.01754386],
#          [0.0212766 , 0.0212766 , 0.0212766 , 0.87234043, 0.0212766 ,
#           0.0212766 , 0.0212766 ],
#          [0.00934579, 0.10280374, 0.00934579, 0.38317757, 0.47663551,
#           0.00934579, 0.00934579],
#          [0.63779528, 0.00787402, 0.16535433, 0.00787402, 0.00787402,
#           0.08661417, 0.08661417],
#          [0.05882353, 0.00280112, 0.75910364, 0.00280112, 0.17086835,
#           0.00280112, 0.00280112],
#          [0.00374532, 0.00374532, 0.97752809, 0.00374532, 0.00374532,
#           0.00374532, 0.00374532],
#          [0.00636943, 0.00636943, 0.96178344, 0.00636943, 0.00636943,
#           0.00636943, 0.00636943],
#          [0.00934579, 0.00934579, 0.85046729, 0.00934579, 0.10280374,
#           0.00934579, 0.00934579],
#          [0.0027248 , 0.0027248 , 0.98365123, 0.0027248 , 0.0027248 ,
#           0.0027248 , 0.0027248 ],
#          [0.01492537, 0.01492537, 0.01492537, 0.01492537, 0.46268657,
#           0.46268657, 0.01492537],
#          [0.02702703, 0.02702703, 0.02702703, 0.02702703, 0.83783784,
#          [0.01149425, 0.01149425, 0.01149425, 0.01149425, 0.93103448,
#           0.01149425, 0.01149425],
#          [0.02702703, 0.02702703, 0.02702703, 0.56756757, 0.02702703,
#           0.2972973 , 0.02702703],
#          [0.44525547, 0.00729927, 0.37226277, 0.15328467, 0.00729927,
#           0.00729927, 0.00729927],
#          [0.00934579, 0.00934579, 0.00934579, 0.00934579, 0.00934579,
#           0.94392523, 0.00934579],
#          [0.00680272, 0.00680272, 0.00680272, 0.00680272, 0.00680272,
#           0.95918367, 0.00680272],
#          [0.00934579, 0.00934579, 0.00934579, 0.00934579, 0.00934579,
#           0.94392523, 0.00934579],
#          [0.06214689, 0.00564972, 0.00564972, 0.00564972, 0.00564972,
#           0.90960452, 0.00564972],
#          [0.32484076, 0.00636943, 0.00636943, 0.00636943, 0.00636943,
#           0.6433121 , 0.00636943],
#          [0.00325733, 0.00325733, 0.85016287, 0.00325733, 0.13355049,
#           0.00325733, 0.00325733],
#          [0.00483092, 0.97101449, 0.00483092, 0.00483092, 0.00483092,
#           0.00483092, 0.00483092],
#          [0.00361011, 0.00361011, 0.00361011, 0.00361011, 0.00361011,
#           0.00361011, 0.97833935],
#          [0.00854701, 0.43589744, 0.00854701, 0.00854701, 0.09401709,
#           0.00854701, 0.43589744],
#          [0.00507614, 0.00507614, 0.00507614, 0.00507614, 0.00507614,
#           0.00507614, 0.96954315],
#          [0.0030581 , 0.0030581 , 0.0030581 , 0.0030581 , 0.0030581 ,
#           0.0030581 , 0.98165138],
#          [0.0030581 , 0.0030581 , 0.0030581 , 0.0030581 , 0.0030581 ,
#           0.0030581 , 0.98165138],
#          [0.00421941, 0.00421941, 0.00421941, 0.00421941, 0.00421941,
#           0.00421941, 0.97468354],
#          [0.00348432, 0.00348432, 0.00348432, 0.03832753, 0.00348432,
#           0.00348432, 0.94425087],
#          [0.00421941, 0.00421941, 0.00421941, 0.00421941, 0.00421941,
#           0.00421941, 0.97468354],
#          [0.27272727, 0.4025974 , 0.27272727, 0.01298701, 0.01298701,
#           0.01298701, 0.01298701],
#          [0.003367  , 0.003367  , 0.003367  , 0.003367  , 0.03703704,
#           0.003367  , 0.94612795],
#          [0.00598802, 0.00598802, 0.00598802, 0.00598802, 0.84431138,
#           0.00598802, 0.1257485 ],
#          [0.00389105, 0.00389105, 0.00389105, 0.00389105, 0.00389105,
#           0.00389105, 0.9766537 ],
#          [0.01030928, 0.01030928, 0.01030928, 0.01030928, 0.11340206,
#           0.01030928, 0.83505155]])))

# %%
# for idx, i in enumerate(dump):
#     if idx == 23:
#         for j in i[3][2]:
#             print(i[3][2][j])

# %%
# %%time
results =  grid_search(N_TOPICS=9, edges_threshold=0.7, lambda_param=1.0)

# %%
results[2]

# %%
# Centroid
# for i in results[2]:
#     a = (results[2][i])
#     avg_dist = []
#     for i in a:
#         sum = 0
#         for  j in a:
#             if i!=j:
#                 distance = get_cosine(embeddings_index[i], embeddings_index[j])
#                 sum += distance
#         avg_dist.append(sum)
#     print(np.array(avg_dist).argmin(), a[np.array(avg_dist).argmin()], a)
