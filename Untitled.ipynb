# %%
import pandas as pd

# %%
with open("icd10_desc.txt") as f:
    icd = f.readlines()

# %%
pd.DataFrame(icd)
# Out:
#                                                        0
# 0      Cholera due to Vibrio cholerae 01, biovar chol...
# 1      Cholera due to Vibrio cholerae 01, biovar elto...
# 2                               Cholera, unspecified\r\n
# 3                         Typhoid fever, unspecified\r\n
# 4                                 Typhoid meningitis\r\n
# 5               Typhoid fever with heart involvement\r\n
# 6                                  Typhoid pneumonia\r\n
# 7                                  Typhoid arthritis\r\n
# 8                              Typhoid osteomyelitis\r\n
# 9             Typhoid fever with other complications\r\n
# 10                               Paratyphoid fever A\r\n
# 11                               Paratyphoid fever B\r\n
# 12                               Paratyphoid fever C\r\n
# 13                    Paratyphoid fever, unspecified\r\n
# 14                              Salmonella enteritis\r\n
# ...
